# %% [markdown]
# # --- Day 1: Trebuchet?! ---

# %%
# --- Support Functions ---
# This section contains support functions used by the main code.

def read_input(file_path):
    with open(file_path, 'r') as file:
        return file.read().splitlines()

# %%
# --- Part ONE ---
input = read_input('input.txt')

# get first number for each line and use it as the first digit
# get last number for each line and use it as the last digit
numbers = []
for line in input:
    n = [int(char) for char in line if char.isdigit()]
    if n:
        numbers.append(10* n[0] + n[-1])

result = sum(numbers)
print("Part ONE:", result)
# Out:
# Part ONE: 55172

# %%
# --- Part TWO ---
input = read_input('input.txt')

# now some numbers can be written as words
# get first number for each line and use it as the first digit
# get last number for each line and use it as the last digit
num_words = {'zero':0, 'one':1, 'two':2, 'three':3, 'four':4,
             'five':5, 'six':6, 'seven':7, 'eight':8, 'nine':9}

numbers = []
for line in input:
    # substitute first word-number with the number
    wnum = sorted([(line.find(w), w) for w in num_words.keys() if line.find(w) >=0])
    if wnum:
        idx, w = wnum[0]
        line = line[:idx]+str(num_words[w])+line[idx+len(w):]

    # substitute last word-number with the number
    wnum = sorted([(line.rfind(w), w) for w in num_words.keys() if line.find(w) >=0], reverse=True)
    if wnum:
        print(wnum)
        idx, w = wnum[0]
        line = line[:idx]+str(num_words[w])+line[idx+len(w):]

    n = [int(char) for char in line if char.isdigit()]
    if n:
        numbers.append(10* n[0] + n[-1])

result = sum(numbers)
# print(numbers)
print("Part TWO:", result)
# Out:
# [(2, 'seven')]
# [(19, 'two'), (13, 'three')]
# [(13, 'two')]
# [(3, 'eight')]
# [(24, 'six'), (20, 'five'), (16, 'four'), (7, 'eight'), (1, 'three')]
# [(12, 'four')]
# [(5, 'three')]
# [(19, 'six'), (11, 'eight'), (6, 'three')]
# [(1, 'five')]
# [(12, 'one'), (2, 'two')]
# [(17, 'one')]
# [(2, 'eight')]
# [(16, 'two'), (10, 'five'), (4, 'nine')]
# [(17, 'nine')]
# [(19, 'one'), (17, 'two')]
# [(4, 'two')]
# [(19, 'six')]
# [(18, 'six'), (4, 'one')]
# [(25, 'one')]
# [(22, 'six')]
# [(2, 'one')]
# [(4, 'seven')]
# [(24, 'three'), (13, 'eight'), (9, 'nine')]
# [(2, 'one')]
# [(3, 'two')]
# [(4, 'nine'), (1, 'two')]
# [(12, 'four'), (2, 'one')]
# [(17, 'nine')]
# [(6, 'five'), (1, 'eight')]
# [(9, 'six'), (1, 'three')]
# [(10, 'three')]
# [(13, 'three'), (10, 'two')]
# [(6, 'eight'), (1, 'six')]
# [(13, 'six'), (7, 'five')]
# [(2, 'five')]
# [(22, 'three')]
# [(10, 'nine'), (7, 'one'), (2, 'seven')]
# [(1, 'nine')]
# [(26, 'two')]
# [(6, 'five')]
# [(7, 'four')]
# [(8, 'one'), (2, 'seven')]
# [(20, 'four')]
# [(3, 'nine')]
# [(8, 'three')]
# [(24, 'three'), (11, 'two')]
# [(23, 'two')]
# [(20, 'six'), (14, 'eight')]
# [(19, 'nine')]
# [(8, 'five')]
# [(14, 'one')]
# [(10, 'eight'), (8, 'one')]
# [(29, 'five'), (20, 'nine')]
# [(4, 'two')]
# [(26, 'two')]
# [(5, 'two')]
# [(16, 'eight')]
# [(12, 'five'), (6, 'eight')]
# [(22, 'five'), (19, 'six'), (16, 'one')]
# [(6, 'three'), (2, 'five')]
# [(14, 'seven'), (11, 'one')]
# [(2, 'five')]
# [(2, 'two')]
# [(17, 'four'), (2, 'two')]
# [(12, 'four'), (6, 'seven'), (2, 'five')]
# [(15, 'two')]
# [(22, 'three'), (16, 'one'), (1, 'six')]
# [(16, 'five'), (2, 'eight')]
# [(12, 'three'), (5, 'nine'), (2, 'six')]
# [(3, 'nine')]
# [(15, 'seven'), (10, 'three'), (1, 'nine')]
# [(15, 'one'), (10, 'seven')]
# [(18, 'one'), (15, 'six'), (10, 'eight')]
# [(7, 'six'), (1, 'one')]
# [(17, 'two'), (12, 'eight'), (7, 'nine'), (2, 'five')]
# [(2, 'eight')]
# [(25, 'four'), (16, 'seven')]
# [(17, 'four')]
# [(26, 'seven'), (23, 'two'), (10, 'eight')]
# [(16, 'five')]
# [(7, 'eight'), (1, 'three')]
# [(19, 'one'), (17, 'two')]
# [(10, 'six')]
# [(2, 'six')]
# [(24, 'one'), (22, 'two'), (16, 'eight')]
# [(7, 'two')]
# [(6, 'six')]
# [(7, 'eight'), (2, 'two')]
# [(29, 'nine'), (16, 'seven')]
# [(9, 'nine'), (2, 'three')]
# [(1, 'six')]
# [(20, 'seven'), (15, 'five'), (2, 'two')]
# [(10, 'one'), (7, 'six'), (1, 'seven')]
# [(23, 'one'), (21, 'two'), (17, 'four'), (12, 'eight'), (4, 'six')]
# [(20, 'four'), (5, 'three')]
# [(17, 'three'), (14, 'two'), (9, 'seven')]
# [(18, 'five'), (13, 'nine')]
# [(33, 'three'), (30, 'one'), (25, 'seven')]
# [(5, 'two')]
# [(29, 'nine'), (20, 'seven')]
# [(16, 'six'), (3, 'seven')]
# [(27, 'seven')]
# [(30, 'four'), (25, 'three'), (20, 'seven'), (17, 'six')]
# [(12, 'one')]
# [(7, 'seven')]
# [(15, 'six'), (7, 'seven')]
# [(16, 'six'), (3, 'seven')]
# [(10, 'three'), (7, 'six'), (2, 'eight')]
# [(16, 'four')]
# [(8, 'four')]
# [(25, 'nine'), (18, 'six'), (14, 'four')]
# [(11, 'eight'), (2, 'one')]
# [(8, 'nine')]
# [(20, 'two')]
# [(9, 'six')]
# [(1, 'nine')]
# [(10, 'nine'), (7, 'six')]
# [(21, 'three'), (10, 'four')]
# [(15, 'eight'), (6, 'five')]
# [(9, 'six'), (5, 'one')]
# [(17, 'six'), (7, 'five'), (2, 'four')]
# [(27, 'five')]
# [(18, 'four'), (15, 'one'), (12, 'two')]
# [(11, 'four'), (7, 'nine')]
# [(16, 'two'), (12, 'eight')]
# [(1, 'six')]
# [(24, 'seven'), (21, 'two')]
# [(21, 'one'), (19, 'two'), (14, 'four'), (10, 'five'), (6, 'nine')]
# [(20, 'seven')]
# [(9, 'nine'), (6, 'two'), (1, 'six')]
# [(31, 'six'), (26, 'nine'), (2, 'eight')]
# [(15, 'seven'), (2, 'eight')]
# [(3, 'five')]
# [(9, 'seven')]
# [(28, 'seven'), (19, 'one')]
# [(12, 'two'), (5, 'five'), (1, 'four')]
# [(23, 'six'), (10, 'one'), (7, 'two'), (2, 'five')]
# [(10, 'nine')]
# [(9, 'six'), (4, 'three')]
# [(13, 'five')]
# [(29, 'nine'), (26, 'two'), (11, 'five')]
# [(6, 'six'), (1, 'one')]
# [(34, 'three'), (19, 'seven'), (15, 'four'), (11, 'two')]
# [(12, 'one'), (9, 'two')]
# [(10, 'eight')]
# [(2, 'one')]
# [(30, 'two'), (24, 'three'), (3, 'nine')]
# [(1, 'eight')]
# [(8, 'eight'), (6, 'one'), (1, 'four')]
# [(7, 'three'), (2, 'four')]
# [(11, 'eight')]
# [(11, 'five')]
# [(13, 'eight')]
# [(19, 'two'), (9, 'eight'), (5, 'nine'), (1, 'one')]
# [(1, 'four')]
# [(30, 'four'), (7, 'eight'), (1, 'three')]
# [(3, 'one')]
# [(9, 'eight')]
# [(14, 'seven'), (11, 'two'), (6, 'eight')]
# [(21, 'five'), (1, 'seven')]
# [(20, 'two')]
# [(6, 'six')]
# [(7, 'two'), (2, 'five')]
# [(8, 'three')]
# [(18, 'eight'), (14, 'one')]
# [(2, 'seven')]
# [(4, 'nine')]
# [(16, 'six')]
# [(19, 'five'), (14, 'three'), (9, 'eight'), (1, 'nine')]
# [(1, 'five')]
# [(1, 'six')]
# [(17, 'seven'), (12, 'three'), (9, 'six'), (5, 'five')]
# [(11, 'one')]
# [(2, 'five')]
# [(11, 'seven'), (7, 'five'), (2, 'one')]
# [(28, 'four')]
# [(22, 'seven')]
# [(6, 'nine')]
# [(19, 'seven'), (14, 'three')]
# [(9, 'three'), (5, 'five'), (1, 'two')]
# [(6, 'four'), (2, 'nine')]
# [(2, 'two')]
# [(6, 'eight'), (2, 'four')]
# [(29, 'two'), (25, 'eight'), (21, 'four'), (16, 'three')]
# [(17, 'one'), (4, 'eight')]
# [(3, 'two')]
# [(19, 'three')]
# [(2, 'seven')]
# [(25, 'three'), (14, 'nine')]
# [(19, 'five')]
# [(22, 'one'), (16, 'seven'), (13, 'two')]
# [(7, 'nine')]
# [(27, 'eight'), (22, 'three')]
# [(15, 'one'), (12, 'two'), (8, 'four')]
# [(14, 'six'), (11, 'two')]
# [(7, 'nine'), (2, 'seven')]
# [(6, 'two'), (2, 'eight')]
# [(10, 'four')]
# [(25, 'three')]
# [(8, 'four'), (4, 'nine')]
# [(3, 'six')]
# [(23, 'two'), (6, 'seven')]
# [(17, 'seven'), (14, 'six'), (9, 'eight'), (6, 'one')]
# [(36, 'one'), (25, 'four'), (20, 'three')]
# [(23, 'three'), (19, 'nine'), (5, 'one'), (1, 'six')]
# [(17, 'five'), (7, 'three')]
# [(11, 'one')]
# [(9, 'eight'), (2, 'three')]
# [(17, 'nine')]
# [(17, 'four'), (2, 'five')]
# [(16, 'seven')]
# [(2, 'two')]
# [(13, 'eight')]
# [(3, 'eight')]
# [(6, 'two')]
# [(15, 'five'), (9, 'nine')]
# [(22, 'four'), (6, 'three'), (1, 'one')]
# [(5, 'eight')]
# [(2, 'one')]
# [(14, 'four'), (2, 'five')]
# [(3, 'two')]
# [(7, 'six'), (2, 'eight')]
# [(5, 'nine'), (2, 'six')]
# [(3, 'eight')]
# [(7, 'six'), (2, 'seven')]
# [(31, 'one')]
# [(18, 'one'), (9, 'six')]
# [(11, 'three'), (7, 'one')]
# [(21, 'seven'), (17, 'six'), (13, 'four')]
# [(14, 'nine'), (9, 'three'), (1, 'two')]
# [(3, 'seven')]
# [(27, 'one'), (10, 'three'), (2, 'two')]
# [(3, 'five')]
# [(19, 'five'), (14, 'seven')]
# [(15, 'eight'), (1, 'four')]
# [(15, 'nine')]
# [(28, 'one'), (19, 'two')]
# [(7, 'four'), (2, 'six')]
# [(22, 'three'), (17, 'seven')]
# [(17, 'nine')]
# [(21, 'four')]
# [(13, 'nine'), (8, 'four')]
# [(27, 'two'), (21, 'three'), (9, 'one')]
# [(3, 'eight')]
# [(21, 'five')]
# [(1, 'seven')]
# [(17, 'nine'), (12, 'eight'), (3, 'seven')]
# [(2, 'nine')]
# [(4, 'two')]
# [(11, 'three'), (6, 'seven')]
# [(11, 'eight')]
# [(23, 'three'), (17, 'eight')]
# [(20, 'six'), (16, 'nine'), (1, 'seven')]
# [(29, 'five')]
# [(36, 'seven')]
# [(20, 'four')]
# [(16, 'seven'), (11, 'eight'), (8, 'one')]
# [(28, 'three'), (9, 'one')]
# [(21, 'four')]
# [(13, 'six')]
# [(3, 'seven')]
# [(22, 'eight'), (7, 'three')]
# [(14, 'one'), (3, 'nine')]
# [(1, 'two')]
# [(1, 'nine')]
# [(12, 'seven'), (8, 'four')]
# [(5, 'seven')]
# [(4, 'five')]
# [(10, 'four'), (4, 'five')]
# [(13, 'one'), (2, 'nine')]
# [(3, 'six')]
# [(14, 'three')]
# [(9, 'eight'), (5, 'six'), (1, 'four')]
# [(7, 'five'), (3, 'four')]
# [(7, 'three'), (4, 'one')]
# [(1, 'five')]
# [(7, 'seven')]
# [(12, 'one'), (6, 'eight')]
# [(9, 'six'), (5, 'four')]
# [(19, 'two'), (10, 'seven')]
# [(15, 'two')]
# [(16, 'eight'), (3, 'one')]
# [(8, 'nine'), (5, 'six'), (2, 'two')]
# [(17, 'one'), (1, 'seven')]
# [(11, 'eight')]
# [(9, 'nine'), (6, 'six')]
# [(11, 'three'), (8, 'one'), (4, 'nine')]
# [(10, 'eight'), (4, 'four')]
# [(22, 'one'), (18, 'four'), (12, 'seven'), (9, 'six'), (6, 'two')]
# [(10, 'one')]
# [(19, 'two'), (15, 'eight'), (10, 'five'), (5, 'nine')]
# [(4, 'seven')]
# [(3, 'seven')]
# [(29, 'three'), (1, 'four')]
# [(9, 'nine'), (6, 'one')]
# [(3, 'nine')]
# [(24, 'two'), (17, 'eight')]
# [(9, 'eight'), (1, 'six')]
# [(7, 'two')]
# [(16, 'four'), (4, 'five'), (1, 'two')]
# [(10, 'nine'), (7, 'six'), (2, 'eight')]
# [(11, 'five')]
# [(13, 'nine')]
# [(7, 'nine'), (1, 'three')]
# [(14, 'eight'), (9, 'six')]
# [(21, 'five'), (9, 'four'), (6, 'two')]
# [(14, 'two')]
# [(20, 'seven')]
# [(34, 'five'), (18, 'eight'), (10, 'two')]
# [(17, 'one')]
# [(6, 'six')]
# [(23, 'five')]
# [(6, 'five')]
# [(16, 'two'), (10, 'three')]
# [(18, 'eight'), (7, 'six'), (2, 'seven')]
# [(16, 'two'), (11, 'seven'), (4, 'eight')]
# [(4, 'two')]
# [(18, 'two'), (12, 'seven')]
# [(18, 'four'), (15, 'one'), (10, 'eight')]
# [(10, 'four'), (4, 'seven'), (1, 'one')]
# [(15, 'nine'), (9, 'six')]
# [(10, 'eight')]
# [(1, 'nine')]
# [(22, 'two')]
# [(4, 'nine')]
# [(5, 'one'), (3, 'two')]
# [(14, 'six'), (11, 'one')]
# [(28, 'eight'), (26, 'one'), (17, 'seven'), (2, 'nine')]
# [(30, 'two'), (20, 'five')]
# [(19, 'four')]
# [(25, 'four'), (2, 'three')]
# [(15, 'seven')]
# [(18, 'nine')]
# [(15, 'two'), (10, 'eight'), (5, 'seven')]
# [(22, 'one'), (15, 'four')]
# [(21, 'seven')]
# [(10, 'five')]
# [(2, 'six')]
# [(31, 'one'), (29, 'two'), (17, 'six')]
# [(3, 'two')]
# [(16, 'six'), (2, 'nine')]
# [(13, 'six')]
# [(19, 'four'), (15, 'six')]
# [(3, 'nine')]
# [(16, 'three'), (5, 'two')]
# [(24, 'six')]
# [(33, 'two'), (29, 'eight'), (25, 'five'), (20, 'one'), (15, 'three')]
# [(8, 'two'), (5, 'one'), (1, 'four')]
# [(18, 'eight')]
# [(21, 'five')]
# [(15, 'five'), (5, 'seven')]
# [(11, 'two'), (3, 'six')]
# [(14, 'six')]
# [(28, 'six'), (22, 'seven'), (18, 'nine')]
# [(4, 'six')]
# [(19, 'nine'), (16, 'two')]
# [(8, 'two')]
# [(13, 'two'), (3, 'five')]
# [(15, 'eight'), (2, 'three')]
# [(9, 'one'), (4, 'three')]
# [(21, 'nine'), (15, 'four')]
# [(23, 'six'), (18, 'eight'), (12, 'one'), (8, 'nine')]
# [(5, 'three'), (2, 'two')]
# [(1, 'two')]
# [(14, 'six')]
# [(15, 'eight'), (4, 'nine')]
# [(4, 'one'), (1, 'two')]
# [(15, 'six'), (11, 'five'), (2, 'three')]
# [(11, 'two'), (5, 'four')]
# [(10, 'six')]
# [(19, 'four'), (7, 'two')]
# [(20, 'seven'), (17, 'one'), (12, 'eight')]
# [(29, 'five'), (24, 'seven'), (11, 'four')]
# [(12, 'five')]
# [(6, 'nine')]
# [(14, 'seven'), (10, 'four'), (4, 'three'), (1, 'six')]
# [(10, 'nine'), (5, 'eight'), (1, 'two')]
# [(42, 'two'), (38, 'eight'), (1, 'nine')]
# [(8, 'nine')]
# [(23, 'four'), (16, 'six')]
# [(14, 'five')]
# [(11, 'nine'), (6, 'three'), (2, 'one')]
# [(2, 'eight')]
# [(31, 'six')]
# [(6, 'five'), (1, 'six')]
# [(18, 'eight'), (13, 'four'), (8, 'two')]
# [(28, 'two'), (24, 'eight'), (14, 'four'), (2, 'three')]
# [(9, 'four')]
# [(3, 'one')]
# [(17, 'seven'), (14, 'one'), (2, 'four')]
# [(19, 'three')]
# [(13, 'six')]
# [(30, 'four'), (5, 'five'), (2, 'six')]
# [(20, 'five'), (17, 'one'), (12, 'seven'), (8, 'four')]
# [(32, 'three')]
# [(20, 'one'), (14, 'eight')]
# [(3, 'eight')]
# [(17, 'eight'), (12, 'nine')]
# [(15, 'eight')]
# [(29, 'one'), (25, 'four')]
# [(10, 'seven')]
# [(5, 'eight'), (1, 'two')]
# [(15, 'seven')]
# [(28, 'three'), (17, 'one')]
# [(8, 'one'), (3, 'three')]
# [(3, 'eight')]
# [(19, 'six')]
# [(9, 'three'), (6, 'two'), (1, 'five')]
# [(20, 'one'), (12, 'six')]
# [(3, 'one')]
# [(2, 'six')]
# [(24, 'six'), (15, 'nine'), (11, 'four')]
# [(26, 'two'), (12, 'eight'), (7, 'three')]
# [(2, 'five')]
# [(22, 'one'), (17, 'five'), (11, 'two')]
# [(5, 'seven'), (1, 'six')]
# [(5, 'three')]
# [(12, 'five'), (8, 'four'), (5, 'two')]
# [(39, 'seven'), (4, 'nine')]
# [(24, 'one'), (11, 'four')]
# [(22, 'two'), (10, 'five')]
# [(3, 'seven')]
# [(23, 'five'), (10, 'six')]
# [(28, 'eight')]
# [(12, 'two')]
# [(4, 'two')]
# [(11, 'six'), (7, 'four')]
# [(1, 'one')]
# [(14, 'one'), (2, 'six')]
# [(4, 'two'), (1, 'one')]
# [(10, 'four')]
# [(12, 'nine')]
# [(1, 'nine')]
# [(31, 'nine'), (26, 'five')]
# [(10, 'three')]
# [(4, 'four')]
# [(16, 'one'), (8, 'four')]
# [(13, 'two')]
# [(26, 'three')]
# [(16, 'seven')]
# [(7, 'seven'), (2, 'eight')]
# [(1, 'nine')]
# [(20, 'eight'), (16, 'nine'), (13, 'two'), (10, 'one')]
# [(29, 'three')]
# [(8, 'one'), (1, 'three')]
# [(1, 'six')]
# [(9, 'six')]
# [(3, 'six')]
# [(12, 'three'), (7, 'seven'), (2, 'nine')]
# [(14, 'eight'), (10, 'six')]
# [(8, 'six'), (3, 'four')]
# [(7, 'five'), (1, 'nine')]
# [(13, 'eight'), (8, 'three')]
# [(7, 'six'), (1, 'eight')]
# [(10, 'one')]
# [(4, 'seven')]
# [(11, 'nine'), (7, 'five'), (2, 'one')]
# [(3, 'nine')]
# [(1, 'nine')]
# [(27, 'nine'), (24, 'six'), (9, 'one')]
# [(13, 'one')]
# [(16, 'eight')]
# [(22, 'six'), (19, 'two'), (14, 'seven')]
# [(2, 'seven')]
# [(15, 'two')]
# [(16, 'two')]
# [(20, 'five'), (17, 'one'), (13, 'four')]
# [(15, 'seven')]
# [(9, 'five'), (4, 'seven')]
# [(24, 'one'), (10, 'nine')]
# [(5, 'five')]
# [(2, 'five')]
# [(11, 'seven')]
# [(4, 'nine')]
# [(30, 'five'), (23, 'eight'), (18, 'two'), (5, 'nine')]
# [(11, 'three'), (6, 'four'), (1, 'eight')]
# [(7, 'four'), (2, 'nine')]
# [(2, 'three')]
# [(18, 'four'), (14, 'two'), (11, 'one')]
# [(13, 'three'), (9, 'five'), (2, 'one')]
# [(13, 'six'), (8, 'eight'), (5, 'one')]
# [(10, 'four'), (5, 'eight')]
# [(3, 'four')]
# [(4, 'seven')]
# [(16, 'six'), (10, 'three')]
# [(7, 'nine'), (2, 'five')]
# [(33, 'two')]
# [(9, 'eight'), (1, 'six')]
# [(16, 'eight'), (11, 'nine'), (7, 'four'), (4, 'one')]
# [(7, 'six')]
# [(11, 'one'), (3, 'four')]
# [(19, 'seven')]
# [(13, 'one'), (9, 'four')]
# [(10, 'seven'), (5, 'three'), (1, 'six')]
# [(18, 'six'), (14, 'nine'), (11, 'one')]
# [(37, 'six'), (26, 'nine')]
# [(20, 'seven'), (4, 'six')]
# [(22, 'three'), (18, 'six'), (10, 'nine')]
# [(12, 'one'), (6, 'seven')]
# [(1, 'seven')]
# [(10, 'three')]
# [(16, 'two'), (1, 'six')]
# [(17, 'four'), (13, 'five')]
# [(11, 'six'), (7, 'five')]
# [(21, 'eight'), (17, 'five'), (12, 'four'), (1, 'six')]
# [(8, 'six')]
# [(9, 'one')]
# [(2, 'four')]
# [(18, 'seven')]
# [(25, 'two'), (21, 'eight')]
# [(13, 'nine')]
# [(25, 'five'), (19, 'nine')]
# [(6, 'six')]
# [(30, 'eight'), (28, 'one')]
# [(12, 'eight'), (3, 'five')]
# [(8, 'nine')]
# [(29, 'six')]
# [(15, 'five'), (11, 'four')]
# [(20, 'five'), (16, 'nine')]
# [(12, 'eight'), (2, 'six')]
# [(9, 'three'), (5, 'one'), (2, 'six')]
# [(1, 'two')]
# [(2, 'two')]
# [(19, 'one')]
# [(2, 'one')]
# [(22, 'nine'), (11, 'five')]
# [(6, 'six'), (1, 'four')]
# [(6, 'nine')]
# [(5, 'five')]
# [(7, 'nine'), (2, 'eight')]
# [(10, 'two')]
# [(16, 'five'), (12, 'nine'), (7, 'three'), (2, 'seven')]
# [(9, 'nine')]
# [(8, 'seven')]
# [(11, 'two'), (7, 'four'), (4, 'six')]
# [(3, 'eight')]
# [(8, 'four'), (3, 'seven')]
# [(11, 'one'), (1, 'five')]
# [(14, 'one'), (12, 'two')]
# [(10, 'nine')]
# [(22, 'nine'), (11, 'two')]
# [(17, 'six'), (14, 'one'), (3, 'three')]
# [(26, 'five'), (22, 'nine')]
# [(2, 'five')]
# [(2, 'five')]
# [(21, 'five')]
# [(8, 'three'), (5, 'two'), (2, 'one')]
# [(2, 'seven')]
# [(9, 'one')]
# [(3, 'eight')]
# [(8, 'two')]
# [(7, 'one'), (2, 'four')]
# [(21, 'six'), (16, 'four'), (11, 'three'), (7, 'nine')]
# [(14, 'one'), (12, 'two')]
# [(23, 'nine')]
# [(11, 'six'), (8, 'two')]
# [(10, 'seven')]
# [(34, 'three'), (4, 'seven')]
# [(26, 'four'), (23, 'six')]
# [(21, 'six'), (18, 'one')]
# [(28, 'three')]
# [(18, 'eight'), (2, 'five')]
# [(19, 'one'), (2, 'three')]
# Part TWO: 54924
